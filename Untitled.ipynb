# %%
import pandas as pd

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
titanic = pd.read_csv("tested.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic.shape
# Out:
# (418, 12)

# %%
titanic.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
# 15          907         1       2
# 16          908         0       2
# 17          909         0       3
# 18          910         1       3
# 19          911         1       3
# 20          912         0       1
# 21          913         0       3
# 22          914         1       1
# 23          915         0       1
# 24          916         1       1
# 25          917         0       3
# ...

# %%
titanic["Name"][4]
# Out:
# 'Hirvonen, Mrs. Alexander (Helga E Lindqvist)'

# %%
titanic.iloc[:5, 3]

# .iloc[baris, kolom]
# Out:
# 0                                Kelly, Mr. James
# 1                Wilkes, Mrs. James (Ellen Needs)
# 2                       Myles, Mr. Thomas Francis
# 3                                Wirz, Mr. Albert
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# Name: Name, dtype: object

# %%
titanic.loc[:5, ['Name', 'Sex', 'Age']]
# Out:
#                                            Name     Sex   Age
# 0                              Kelly, Mr. James    male  34.5
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                     Myles, Mr. Thomas Francis    male  62.0
# 3                              Wirz, Mr. Albert    male  27.0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 5                    Svensson, Mr. Johan Cervin    male  14.0

# %%
titanic.loc[(titanic.Sex == "female") & (titanic.Age <= 20)]
# Out:
#      PassengerId  Survived  Pclass  \
# 8            900         1       3
# 52           944         1       2
# 66           958         1       3
# 87           979         1       3
# 98           990         1       3
# 104          996         1       3
# 113         1005         1       3
# 117         1009         1       3
# 120         1012         1       2
# 125         1017         1       3
# 140         1032         1       3
# 175         1067         1       2
# 176         1068         1       2
# 182         1074         1       1
# 197         1089         1       3
# 203         1095         1       2
# 238         1130         1       2
# 250         1142         1       2
# 258         1150         1       2
# 263         1155         1       3
# 275         1167         1       2
# 283         1175         1       3
# 284         1176         1       3
# 296         1188         1       2
# 315         1207         1       3
# ...

# %%
# asumsi, yg selamat itu perempuan atau laki-laki dibawah usia 9 tahun
titanic.loc[(titanic.Sex == "female") | (titanic.Age <= 9)].head(50)
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# 14           906         1       1
# 15           907         1       2
# 18           910         1       3
# 19           911         1       3
# 21           913         0       3
# 22           914         1       1
# 24           916         1       1
# 26           918         1       1
# 32           924         1       3
# 33           925         1       3
# 36           928         1       3
# 37           929         1       3
# 43           935         1       2
# 44           936         1       1
# 48           940         1       1
# 49           941         1       3
# 52           944         1       2
# 53           945         1       1
# 59           951         1       1
# 63           955         1       3
# ...

# %%
titanic.loc[titanic.Embarked.isin(['Q', 'C'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 2            894         0       2
# 6            898         1       3
# 8            900         1       3
# 15           907         1       2
# ..           ...       ...     ...
# 408         1300         1       3
# 410         1302         1       3
# 411         1303         1       1
# 414         1306         1       1
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 15     del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
titanic.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 3                                    Wirz, Mr. Albert    male  27.0      0
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
titanic = titanic.drop("Cabin", axis=1)
titanic.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Embarked        0
# dtype: int64

# %%
titanic.Age = titanic.Age.fillna(titanic.Age.mean())
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# dtype: int64

# %%
import matplotlib as plt

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          418 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 36.0+ KB

# %%
titanic = titanic.dropna()
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   417.000000  417.000000  417.000000  417.000000  417.000000
# mean   1100.635492    0.364508    2.263789   30.200103    0.448441
# std     120.923774    0.481870    0.842077   12.562386    0.897568
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.000000    0.000000    1.000000   23.000000    0.000000
# 50%    1101.000000    0.000000    3.000000   30.272590    0.000000
# 75%    1205.000000    1.000000    3.000000   35.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  417.000000  417.000000
# mean     0.393285   35.627188
# std      0.982419   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
# %matplotlib inline
from matplotlib import pyplot
plt.pyplot.hist(titanic["Age"])

# set x/y labels and plot title
plt.pyplot.xlabel("Age")
plt.pyplot.ylabel("total")
plt.pyplot.title("age bins")
# Out:
# Text(0.5, 1.0, 'age bins')

# %%
import numpy as np

bins = np.linspace(min(titanic["Age"]), max(titanic["Age"]), 6)
bins
# Out:
# array([ 0.17 , 15.336, 30.502, 45.668, 60.834, 76.   ])

# %%
group_names = ['muda', 'remaja', 'dewasa', 'tua', 'lansia']

# %%
titanic['Age-binned'] = pd.cut(titanic['Age'], bins, labels=group_names, include_lowest=True )
titanic[['Age','Age-binned']].head(20)
# Out:
# C:\Users\Sayyid\AppData\Local\Temp\ipykernel_9388\3181585151.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['Age-binned'] = pd.cut(titanic['Age'], bins, labels=group_names, include_lowest=True )
#          Age Age-binned
# 0   34.50000     dewasa
# 1   47.00000        tua
# 2   62.00000     lansia
# 3   27.00000     remaja
# 4   22.00000     remaja
# 5   14.00000       muda
# 6   30.00000     remaja
# 7   26.00000     remaja
# 8   18.00000     remaja
# 9   21.00000     remaja
# 10  30.27259     remaja
# 11  46.00000        tua
# 12  23.00000     remaja
# 13  63.00000     lansia
# 14  47.00000        tua
# 15  24.00000     remaja
# 16  35.00000     dewasa
# 17  21.00000     remaja
# 18  27.00000     remaja
# ...

# %%
# draw historgram of attribute "horsepower" with bins = 3
plt.pyplot.hist(titanic["Age"], bins = 6)

# set x/y labels and plot title
plt.pyplot.xlabel("age")
plt.pyplot.ylabel("total")
plt.pyplot.title("age bins")
# Out:
# Text(0.5, 1.0, 'age bins')

# %%
titanic.to_csv("titanic.csv")
